# %%
import matplotlib.pyplot as plt
import numpy as np
import random 

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [20 21 34 29 38 22 20 21 31 27 16 50 24 41 11 52 35 31 19 43 52 59 58 59
#  40 20 31 34 47 25 38 21 25 25 41 42 45 43 13 22 13 47 39 34 31 51 11 33
#  33 52]

# %%
no=[20,21, 34, 29, 38, 22, 20, 21, 31, 27, 16, 50, 24, 41, 11, 52, 35, 31, 19, 43, 52, 59, 58, 59
, 40, 20, 31, 34, 47, 25, 38, 21, 25, 25, 41, 42, 45, 43, 13, 22, 13, 47, 39, 34, 31, 51, 11, 33,
 33, 52]
l=[10,20,30,40,50,60]
plt.hist(no,bins=l)

plt.title('graph')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
no=[20,21, 34, 29, 38, 22, 20, 21, 31, 27, 16, 50, 24, 41, 11, 52, 35, 31, 19, 43, 52, 59, 58, 59
, 40, 20, 31, 34, 47, 25, 38, 21, 25, 25, 41, 42, 45, 43, 13, 22, 13, 47, 39, 34, 31, 51, 11, 33,
 33, 52]
l=[10,20,30,40,50,60]
plt.hist(no,'auto',(0,100),cumulative=-1)

plt.title('graph')

plt.show
# Out:
# C:\Users\ashaa\AppData\Local\Temp\ipykernel_12968\4209808434.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(no,'auto',(0,100),cumulative=-1)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
no=[20,21, 34, 29, 38, 22, 20, 21, 31, 27, 16, 50, 24, 41, 11, 52, 35, 31, 19, 43, 52, 59, 58, 59
, 40, 20, 31, 34, 47, 25, 38, 21, 25, 25, 41, 42, 45, 43, 13, 22, 13, 47, 39, 34, 31, 51, 11, 33,
 33, 52]
l=[10,20,30,40,50,60]
plt.hist(no,'auto',(0,100),bottom=20,histtype='step')

plt.title('graph')

plt.show
# Out:
# C:\Users\ashaa\AppData\Local\Temp\ipykernel_12968\782386306.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(no,'auto',(0,100),bottom=20,histtype='step')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
no=[20,21, 34, 29, 38, 22, 20, 21, 31, 27, 16, 50, 24, 41, 11, 52, 35, 31, 19, 43, 52, 59, 58, 59
, 40, 20, 31, 34, 47, 25, 38, 21, 25, 25, 41, 42, 45, 43, 13, 22, 13, 47, 39, 34, 31, 51, 11, 33,
 33, 52]
l=[10,20,30,40,50,60]
plt.hist(no,'auto',(0,100),rwidth=0.8)

plt.title('graph')

plt.show
# Out:
# C:\Users\ashaa\AppData\Local\Temp\ipykernel_12968\1090451498.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(no,'auto',(0,100),rwidth=0.8)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
no=[20,21, 34, 29, 38, 22, 20, 21, 31, 27, 16, 50, 24, 41, 11, 52, 35, 31, 19, 43, 52, 59, 58, 59
, 40, 20, 31, 34, 47, 25, 38, 21, 25, 25, 41, 42, 45, 43, 13, 22, 13, 47, 39, 34, 31, 51, 11, 33,
 33, 52]
l=[10,20,30,40,50,60]
plt.hist(no,'auto',(0,100),log=True)

plt.title('graph')

plt.show
# Out:
# C:\Users\ashaa\AppData\Local\Temp\ipykernel_12968\2389022361.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(no,'auto',(0,100),log=True)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
no=[20,21, 34, 29, 38, 22, 20, 21, 31, 27, 16, 50, 24, 41, 11, 52, 35, 31, 19, 43, 52, 59, 58, 59
, 40, 20, 31, 34, 47, 25, 38, 21, 25, 25, 41, 42, 45, 43, 13, 22, 13, 47, 39, 34, 31, 51, 11, 33,
 33, 52]
l=[10,20,30,40,50,60]
plt.hist(no,'auto',(0,100),label='python')

plt.title('graph')
plt.legend()
plt.grid()
plt.show
# Out:
# C:\Users\ashaa\AppData\Local\Temp\ipykernel_12968\3224838023.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(no,'auto',(0,100),label='python')
# <function matplotlib.pyplot.show(close=None, block=None)>
