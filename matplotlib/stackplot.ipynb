# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[2,4,6,8]
plt.stackplot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
area1=[2,4,6,8]
area2=[4,8,6,2]
area3=[1,9,6,8]
plt.stackplot(x,area1,area2,area3)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
area1=[2,4,6,8]
area2=[4,8,6,2]
area3=[1,9,6,8]

l=["area1","area2","area3"]

plt.stackplot(x,area1,area2,area3)

plt.legend(loc=2)
plt.show()
# Out:
# C:\Users\ashaa\AppData\Local\Temp\ipykernel_7580\1206247776.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc=2)
