# %%
import numpy as np 

var = np.array([13  ,8 ,10, 13])
varadd = var +5
print(varadd)
# Out:
# [18 13 15 18]

# %%
 
var1= np.array([1,2,3,4])
var2 = np.array([13  ,8 ,10, 13])
varadd = var1 + var2
print(varadd)
# Out:
# [14 10 13 17]

# %%
var1= np.array([1,2,3,4])
var2 = np.array([13  ,8 ,10, 13])
varsub = var1 - var2
print(varsub)
# Out:
# [-12  -6  -7  -9]

# %%
var1= np.array([1,2,3,4])
var2 = np.array([13  ,8 ,10, 13])
varadd = var1 * var2
print(varadd)
# Out:
# [13 16 30 52]

# %%
var1= np.array([1,2,3,4])
var2 = np.array([13  ,8 ,10, 13])
varadd = var1/var2
print(varadd)
# Out:
# [0.07692308 0.25       0.3        0.30769231]

# %%
var1= np.array([1,2,3,4])
var2 = np.array([13  ,8 ,10, 13])
varadd = np.add(var1,var2)
print(varadd)
# Out:
# [14 10 13 17]

# %%
var11= np.array([[1,2,3,4],[1,2,3,4]])
var21 = np.array([[1,2,3,4],[1,2,3,4]])

varadd = np.add(var11,var21)
print(varadd)
# Out:
# [[2 4 6 8]
#  [2 4 6 8]]

# %%
import numpy as np 

var = np.array([13  ,8 ,10, 13])
varadd =np.reciprocal(var)
print(varadd)
# Out:
# [0 0 0 0]
