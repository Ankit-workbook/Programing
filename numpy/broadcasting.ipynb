# %%
import numpy as np

var1=np.array([1,2,3,4])
var2=np.array([1,2,3,4])

print(var1+var2)
# Out:
# [2 4 6 8]

# %%
import numpy as np

var1=np.array([[1,2,3,4]])
print(var1.shape)
print()
print(var1)
print()

var2=np.array([[1,2,3,4]])
print(var2.shape)
print()
print(var2)
print()
print(var1+var2)
# Out:
# (1, 4)
#
# [[1 2 3 4]]
#
# (1, 4)
#
# [[1 2 3 4]]
#
# [[2 4 6 8]]

# %%
x=np.array([[1],[2]])
print(x.shape)

y=np.array([[1,2,3],[1,2,3]])
print(y.shape)

print(x+y)
# Out:
# (2, 1)
# (2, 3)
# [[2 3 4]
#  [3 4 5]]
