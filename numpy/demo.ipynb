# %%
import numpy as np

x= np.array([1,2,3,4])
print(x)
print(type(x))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
# %timeit [j**4 for j in range(1,9)]
# Out:
# 766 ns ± 38 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
import numpy as np

# %timeit np.arange(1,9)**4
# Out:
# 4.49 μs ± 705 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
